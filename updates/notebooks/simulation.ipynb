# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from datetime import datetime

# Create Spark session with Iceberg support
spark = SparkSession.builder \
    .appName("BackfillSimulation") \
    .getOrCreate()

print(f"Spark Version: {spark.version}")
print(f"Session started at: {datetime.now()}")
# Out:
# Spark Version: 3.5.5
# Session started at: 2026-01-22 12:57:33.164308
# 26/01/22 12:57:33 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
# %%sql
# show databases;
# Out:
# 26/01/22 12:57:36 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# +-----------+
# | namespace |
# +-----------+
# |   default |
# +-----------+

# %%
# %%sql
# show tables in default;
# Out:
# +-----------+----------------+-------------+
# | namespace |      tableName | isTemporary |
# +-----------+----------------+-------------+
# |   default |   accounts_all |       False |
# |   default | latest_summary |       False |
# |   default |        summary |       False |
# +-----------+----------------+-------------+

# %%
# %%sql
# select * from default.latest_summary
# Out:
# +---------------+---------+--------------+---------+------------------+-------------------+------------------+--------------+---------------+----------------+-------------------------+--------------------------------+--------------------------+---------+-----------+----------------+-----------------+---------+------------+---------------+-------------+---------------+-------------------+-----------------+--------------+---------------+----------------------+---------------------------+--------------------+-------------------------+---------------------+---------------------------+-----------------------+------------------------+
# ...

# %%
# %%sql
# select cons_acct_key,rpt_as_of_mo from default.accounts_all order by cons_acct_key, rpt_as_of_mo
# Out:
# +---------------+--------------+
# | cons_acct_key | rpt_as_of_mo |
# +---------------+--------------+
# |             1 |      2016-01 |
# |             1 |      2016-02 |
# |             1 |      2016-03 |
# |             1 |      2016-04 |
# |             1 |      2016-05 |
# |             1 |      2016-06 |
# |             1 |      2016-07 |
# |             1 |      2016-08 |
# |             1 |      2016-09 |
# |             1 |      2016-10 |
# |             1 |      2016-11 |
# |             1 |      2016-12 |
# |             1 |      2017-01 |
# |             1 |      2017-02 |
# |             1 |      2017-03 |
# |             1 |      2017-04 |
# |             1 |      2017-05 |
# |             1 |      2017-06 |
# |             1 |      2017-07 |
# |             1 |      2017-08 |
# |             1 |      2017-09 |
# |             1 |      2017-10 |
# |             1 |      2017-11 |
# |             1 |      2017-12 |
# |             1 |      2018-01 |
# ...

# %%
# %%sql
# select cons_acct_key, count(distinct cons_acct_key, rpt_as_of_mo) from default.accounts_all group by cons_acct_key
# Out:
# +---------------+---------------------------------------------+
# | cons_acct_key | count(DISTINCT cons_acct_key, rpt_as_of_mo) |
# +---------------+---------------------------------------------+
# |             5 |                                         120 |
# |             1 |                                         120 |
# |             3 |                                         120 |
# |             2 |                                         119 |
# |             4 |                                         120 |
# +---------------+---------------------------------------------+

# %%
# %%sql
# select cons_acct_key, rpt_as_of_mo from default.accounts_all where cons_acct_key =2 order by rpt_as_of_mo
# Out:
# +---------------+--------------+
# | cons_acct_key | rpt_as_of_mo |
# +---------------+--------------+
# |             2 |      2016-01 |
# |             2 |      2016-02 |
# |             2 |      2016-03 |
# |             2 |      2016-04 |
# |             2 |      2016-05 |
# |             2 |      2016-06 |
# |             2 |      2016-07 |
# |             2 |      2016-09 |
# |             2 |      2016-10 |
# |             2 |      2016-11 |
# |             2 |      2016-12 |
# |             2 |      2017-01 |
# |             2 |      2017-02 |
# |             2 |      2017-03 |
# |             2 |      2017-04 |
# |             2 |      2017-05 |
# |             2 |      2017-06 |
# |             2 |      2017-07 |
# |             2 |      2017-08 |
# |             2 |      2017-09 |
# |             2 |      2017-10 |
# |             2 |      2017-11 |
# |             2 |      2017-12 |
# |             2 |      2018-01 |
# |             2 |      2018-02 |
# ...
