# %%
spark.read.table("default.summary").show(5)
# Out:
# +-------------+------------+--------------------+--------------------+--------------------+--------------------+---------------+-----------+--------------+-------------------+-------------------+-------------------+
# |cons_acct_key|rpt_as_of_mo|         bal_history|         dpd_history|     payment_history|      status_history|current_balance|current_dpd|account_status|         created_ts|         updated_ts|            base_ts|
# +-------------+------------+--------------------+--------------------+--------------------+--------------------+---------------+-----------+--------------+-------------------+-------------------+-------------------+
# |            5|     2018-12|[1047, 1046, 1045...|[0, 0, 0, 0, 0, 0...|[50, 50, 50, 50, ...|[0, 0, 0, 0, 0, 0...|           1047|          0|       CURRENT|2018-12-27 15:50:30|2018-12-28 17:50:30|2018-12-27 15:50:30|
# |            5|     2018-11|[1046, 1045, 1044...|[0, 0, 0, 0, 0, 0...|[50, 50, 50, 50, ...|[0, 0, 0, 0, 0, 0...|           1046|          0|       CURRENT|2018-11-27 14:34:08|2018-11-29 12:34:08|2018-11-27 14:34:08|
# |            5|     2018-10|[1045, 1044, 1043...|[0, 0, 0, 0, 0, 0...|[50, 50, 50, 50, ...|[0, 0, 0, 0, 0, 0...|           1045|          0|       CURRENT|2018-10-25 10:32:15|2018-10-26 03:32:15|2018-10-25 10:32:15|
# |            5|     2022-02|[1085, 1084, 1083...|[0, 0, 0, 0, 0, 0...|[50, 50, 50, 50, ...|[0, 0, 0, 0, 0, 0...|           1085|          0|       CURRENT|2022-02-24 13:47:28|2022-02-26 00:47:28|2022-02-24 13:47:28|
# |            5|     2022-03|[1086, 1085, 1084...|[0, 0, 0, 0, 0, 0...|[50, 50, 50, 50, ...|[0, 0, 0, 0, 0, 0...|           1086|          0|       CURRENT|2022-03-26 08:07:04|2022-03-28 04:07:04|2022-03-26 08:07:04|
# +-------------+------------+--------------------+--------------------+--------------------+--------------------+---------------+-----------+--------------+-------------------+-------------------+-------------------+
# only showing top 5 rows

# %%
spark.read.table("default.summary").write.format("iceberg").mode("overwrite").saveAsTable("default.summary_testing")

# %%
# %%sql
# show tables in default
# Out:
# +-----------+-----------------+-------------+
# | namespace |       tableName | isTemporary |
# +-----------+-----------------+-------------+
# |   default |         summary |       False |
# |   default | summary_testing |       False |
# +-----------+-----------------+-------------+

# %%
# %%sql
# -- select count(1) from default.summary
# select count(1) from default.summary;
# Out:
# +----------+
# | count(1) |
# +----------+
# |      147 |
# +----------+

# %%
# %%sql
# with data as (
#     select
#     cons_acct_key,
#     rpt_as_of_mo,
#     row_number() over (partition by cons_acct_key,rpt_as_of_mo order by base_ts) as row_num
#     from default.summary_testing)
# select * from data where row_num > 1
# Out:
# +---------------+--------------+---------+
# | cons_acct_key | rpt_as_of_mo | row_num |
# +---------------+--------------+---------+
# +---------------+--------------+---------+

# %%
# %%sql
# select cons_acct_key, base_ts, rpt_as_of_mo from default.summary_testing where cons_acct_key = 1 order by rpt_as_of_mo
# Out:
# +---------------+---------------------+--------------+
# | cons_acct_key |             base_ts | rpt_as_of_mo |
# +---------------+---------------------+--------------+
# |             1 | 2025-05-20 11:01:47 |      2025-05 |
# |             1 | 2025-06-25 11:43:47 |      2025-06 |
# +---------------+---------------------+--------------+

# %%
df = spark.read.csv("/home/iceberg/data/accounts_all.csv", header=True, inferSchema=True).filter("base_ts < date '2025-07-05'")
df.count()
# Out:
# 153

# %%
# %%sql
# create database if not exists base;
# Out:
# ++
# ||
# ++
# ++

# %%
spark.read.table("default.default.accounts_all").filter("base_ts < date '2025-07-05'").write.format("iceberg").mode("overwrite").saveAsTable("base.accounts_all")

# %%
# %%sql
# select count(1) from base.accounts_all
# Out:
# +----------+
# | count(1) |
# +----------+
# |      153 |
# +----------+

# %%
# %%sql
# describe base.accounts_all
# Out:
# +-----------------+-----------+---------+
# |        col_name | data_type | comment |
# +-----------------+-----------+---------+
# |   cons_acct_key |    bigint |    None |
# |         acct_dt |      date |    None |
# |    rpt_as_of_mo |    string |    None |
# | current_balance |       int |    None |
# |     current_dpd |       int |    None |
# |      payment_am |       int |    None |
# |       status_cd |    string |    None |
# |  account_status |    string |    None |
# |      created_ts | timestamp |    None |
# |      updated_ts | timestamp |    None |
# |         base_ts | timestamp |    None |
# +-----------------+-----------+---------+

# %%
# %%sql
# describe default.default.accounts_all
# Out:
# +-------------------------+-----------+---------+
# |                col_name | data_type | comment |
# +-------------------------+-----------+---------+
# |           cons_acct_key |    bigint |    None |
# |                 acct_dt |      date |    None |
# |            rpt_as_of_mo |    string |    None |
# |         current_balance |       int |    None |
# |             current_dpd |       int |    None |
# |              payment_am |       int |    None |
# |               status_cd |    string |    None |
# |          account_status |    string |    None |
# |              created_ts | timestamp |    None |
# |              updated_ts | timestamp |    None |
# |                 base_ts | timestamp |    None |
# | # Partition Information |           |         |
# |              # col_name | data_type | comment |
# |            rpt_as_of_mo |    string |    None |
# +-------------------------+-----------+---------+

# %%
from pyspark.sql import functions as F

spark.read.table("default.summary_testing").agg(F.max("base_ts").alias("max_base_ts")).show()
# Out:
# +-------------------+
# |        max_base_ts|
# +-------------------+
# |2025-07-03 14:30:00|
# +-------------------+

# %%
from pyspark.sql.functions import col

max_base_ts = spark.table("default.summary_testing").selectExpr("max(base_ts)").collect()[0][0]
accounts_df = spark.table("default.default.accounts_all").filter(col("base_ts") > max_base_ts)

from pyspark.sql.window import Window
from pyspark.sql.functions import row_number

window_spec = Window.partitionBy("cons_acct_key", "rpt_as_of_mo").orderBy(col("base_ts").desc(), col("created_ts").desc(), col("updated_ts").desc())
latest_accounts_df = accounts_df.withColumn("row_num", row_number().over(window_spec)).filter(col("row_num") == 1).drop("row_num")

latest_accounts_df.count()
# Out:
# 108

# %%
latest_accounts_df.show()
# Out:
# [Stage 77:========================================>               (13 + 5) / 18]
# +-------------+----------+------------+---------------+-----------+----------+---------+--------------+-------------------+-------------------+-------------------+
# |cons_acct_key|   acct_dt|rpt_as_of_mo|current_balance|current_dpd|payment_am|status_cd|account_status|         created_ts|         updated_ts|            base_ts|
# +-------------+----------+------------+---------------+-----------+----------+---------+--------------+-------------------+-------------------+-------------------+
# |            1|2023-01-22|     2023-01|           4114|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2023-02-22|     2023-02|           3002|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2023-03-05|     2023-03|           2890|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2023-04-18|     2023-04|           1721|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2023-05-27|     2023-05|           1067|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2023-06-13|     2023-06|           2308|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2023-07-12|     2023-07|           2986|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2023-08-27|     2023-08|           4249|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2023-09-12|     2023-09|           2380|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2023-10-28|     2023-10|           1922|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2023-11-26|     2023-11|           2325|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2023-12-10|     2023-12|           4846|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2024-01-07|     2024-01|           4614|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2024-02-21|     2024-02|           1213|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2024-03-16|     2024-03|           2144|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2024-04-08|     2024-04|           4078|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2024-05-08|     2024-05|           2957|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2024-06-24|     2024-06|           3482|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2024-07-04|     2024-07|           4548|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# |            1|2024-08-02|     2024-08|           3232|          0|        50|        0|       CURRENT|2025-07-05 09:00:00|2025-07-05 09:00:00|2025-07-05 09:00:00|
# +-------------+----------+------------+---------------+-----------+----------+---------+--------------+-------------------+-------------------+-------------------+
# only showing top 20 rows
